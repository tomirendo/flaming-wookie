# %%
# %pylab inline
import timeit
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
pylab.plot([timeit.timeit("sum(i*i for i in range({num}))".format(num = i),number = 1) for i in xrange(0,1000000,5000)])
pylab.plot([timeit.timeit("sum(i*i for i in xrange({num}))".format(num = i),number = 1) for i in xrange(0,1000000,5000)])
